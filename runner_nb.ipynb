# %%
import importlib
import first_etl

importlib.reload(first_etl)
first_etl.run()

# %%
# %pip install pytest
# %restart_python

# %%
#pytest /Workspace/Users/vinilanair11@gmail.com/etl_repo/test_first_etl.py

run pytest tests
